# %%
import plotly.express as px
import pandas as pd

# %% [markdown]
# Code for generating Figure 2. The data tables from `0.percent_replicating.ipynb` and `2.percent_replicating_dl.ipynb` were manually assembled into `input/data.csv`.

# %%
df = pd.read_csv('input/data.csv')

fig = px.bar(data_frame=df,
             x='Perturbation',
             y='Percent_Replicating',
             color='feature_set',
             barmode='group',
             facet_row='time',
             facet_col='Cell')
fig.update_layout(title='Percent Replicating vs. Perturbation',
                  yaxis=dict(title='Percent Replicating'),
                  yaxis3=dict(title='Percent Replicating'))
fig.show("png")
fig.write_image(f'figures/figure_2.png', width=640, height=480, scale=2)
