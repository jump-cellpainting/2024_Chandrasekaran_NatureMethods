# %%
import pandas as pd
import utils
import numpy as np
import plotly.express as px

np.random.seed(9000)

# %% [markdown]
# In this notebook, we calculate the `mean average precision` and `mean Precision@r` values between chemical and genetic perturbations. The following are the steps taken
# 1. Normalized, feature selected ORF, CRISPR and Compound profiles are read and the replicate plates are merged into a single dataframe, for each time point and cell line.
# 2. All the target annotations of the compounds are used in this analysis.
# 3. Negative control and empty wells are removed from the dataframe.
# 4. The replicate profiles are median collapsed.
# 5. Average precision (AP) is computed for each perturbation and the mean average precision (mAP) is computed for each pair of conditions. Similarly, the mean precision@r (mpr) is computed. The precision scores are calculated by challenged the samples against negative control.
# 6. The same is repeated after shuffling the dataframe which is an estimate of the null distribution.
# 7. Table of precision values is printed and bar plots of precision values are plotted.

# %%
precision_df = pd.DataFrame()
batch = "2020_11_04_CPJUMP1"
all_percent_perturbation_df = pd.DataFrame()

experiment_df = (
    pd.read_csv('output/experiment-metadata.tsv', sep='\t')
    .query('Batch==@batch')
    .query('Density=="100"')
    .query('Antibiotics=="absent"')
)

experiment_df.drop(experiment_df[(experiment_df.Perturbation == "compound") & (experiment_df.Cell_line == "Cas9")].index, inplace=True)

target1_metadata = (
    pd.read_csv('input/JUMP-Target-1_compound_metadata_additional_annotations.tsv', sep='\t', usecols=['broad_sample', 'target_list'])
    .rename(columns={'broad_sample':'Metadata_broad_sample', 'target_list':'Metadata_target_list'})
)

# %%
for cell in experiment_df.Cell_type.unique():
    cell_df = experiment_df.query('Cell_type==@cell')
    modality_1_perturbation = "compound"
    modality_1_experiments_df = cell_df.query('Perturbation==@modality_1_perturbation')
    for modality_1_timepoint in modality_1_experiments_df.Time.unique():
        modality_1_timepoint_df = modality_1_experiments_df.query('Time==@modality_1_timepoint')
        modality_1_df = pd.DataFrame()
        for plate in modality_1_timepoint_df.Assay_Plate_Barcode.unique():
            data_df = (
                utils.load_data(batch, plate, "normalized_feature_select_negcon_batch.csv.gz")
                .assign(Metadata_modality=modality_1_perturbation)
            )
            modality_1_df = utils.concat_profiles(modality_1_df, data_df)

        modality_1_df = utils.remove_empty_wells(modality_1_df)
        modality_1_consensus_df = utils.consensus(modality_1_df, "Metadata_broad_sample")

        modality_1_consensus_df = (
            modality_1_consensus_df.merge(target1_metadata, on='Metadata_broad_sample', how='left')
            .assign(Metadata_gene=lambda x: x.Metadata_target_list.str.split('|'))
            .assign(Metadata_gene_list=lambda x: x.Metadata_target_list.str.split('|'))
            .explode('Metadata_gene')
            .reset_index(drop=True)
        )

        modality_1_consensus_shuffled_df = utils.shuffle_profiles(modality_1_consensus_df)

        both_modality_2_experiments_df = cell_df.query('Perturbation!=@modality_1_perturbation')
        for modality_2_perturbation in both_modality_2_experiments_df.Perturbation.unique():
            modality_2_experiments_df = both_modality_2_experiments_df.query('Perturbation==@modality_2_perturbation')
            for modality_2_timepoint in modality_2_experiments_df.Time.unique():
                modality_2_timepoint_df = modality_2_experiments_df.query('Time==@modality_2_timepoint')
                modality_2_df = pd.DataFrame()
                for plate in modality_2_timepoint_df.Assay_Plate_Barcode.unique():
                    data_df = (
                        utils.load_data(batch, plate, "normalized_feature_select_negcon_batch.csv.gz")
                        .assign(Metadata_modality=modality_2_perturbation)
                        .assign(Metadata_gene_list=lambda x: x.Metadata_gene)
                    )
                    modality_2_df = utils.concat_profiles(modality_2_df, data_df)

                modality_2_df = utils.remove_empty_wells(modality_2_df)

                modality_2_consensus_df = utils.consensus(modality_2_df, "Metadata_broad_sample")
                modality_2_consensus_shuffled_df = utils.shuffle_profiles(modality_2_consensus_df)

                modality_2_genes = list(np.unique(list(modality_2_consensus_df.Metadata_gene)))
                modality_1_consensus_filtered_df = modality_1_consensus_df.query('Metadata_gene==@modality_2_genes').reset_index(drop=True)
                modality_1_consensus_shuffled_filtered_df = modality_1_consensus_shuffled_df.query('Metadata_gene==@modality_2_genes').reset_index(drop=True)

                score = utils.PrecisionScores(modality_1_consensus_filtered_df, modality_2_consensus_df, "Metadata_gene", anti_correlation=True, challenge_negcon=True)

                precision_df = precision_df.append({'Description':f'{modality_1_perturbation}_{modality_1_timepoint} vs. {modality_2_perturbation}_{modality_2_timepoint}',
                                                    'Modality1': f'{modality_1_perturbation}_{modality_1_timepoint:03}h',
                                                    'Modality2': f'{modality_2_perturbation}_{modality_2_timepoint:03}h',
                                                    'Cell': cell,
                                                    'mAP':f'{score.map:.3f}',
                                                    'mPr':f'{score.mpr:.3f}',
                                                    'Matches':'Real'}, ignore_index=True)

                score_shuffled = utils.PrecisionScores(modality_1_consensus_shuffled_filtered_df, modality_2_consensus_shuffled_df, "Metadata_gene", anti_correlation=True, challenge_negcon=True)

                precision_df = precision_df.append({'Description':f'{modality_1_perturbation}_{modality_1_timepoint} vs. {modality_2_perturbation}_{modality_2_timepoint}',
                                                    'Modality1': f'{modality_1_perturbation}_{modality_1_timepoint:03}h',
                                                    'Modality2': f'{modality_2_perturbation}_{modality_2_timepoint:03}h',
                                                    'Cell': cell,
                                                    'mAP':f'{score_shuffled.map:.3f}',
                                                    'mPr':f'{score_shuffled.mpr:.3f}',
                                                    'Matches':'Permuted'}, ignore_index=True)

                percent_perturbation_df = utils.precision_at_r_threshold(score.pr_group, score_shuffled.pr_group)
                percent_perturbation_df['Modality1'] = f'{modality_1_perturbation}_{modality_1_timepoint:03}h'
                percent_perturbation_df['Modality2'] = f'{modality_2_perturbation}_{modality_2_timepoint:03}h'
                percent_perturbation_df['Cell'] = f'{cell}'

                all_percent_perturbation_df = utils.concat_profiles(all_percent_perturbation_df, percent_perturbation_df)

# %%
print(precision_df[['Description', 'Cell', 'Modality1', 'Modality2', 'Matches', 'mAP', 'mPr']].query('Matches=="Real"').to_markdown(index=False))
# Out:
# | Description                | Cell   | Modality1     | Modality2   | Matches   |   mAP |   mPr |
# |:---------------------------|:-------|:--------------|:------------|:----------|------:|------:|
# | compound_24 vs. crispr_144 | A549   | compound_024h | crispr_144h | Real      | 0.225 | 0.137 |
# | compound_24 vs. crispr_96  | A549   | compound_024h | crispr_096h | Real      | 0.218 | 0.119 |
# | compound_24 vs. orf_96     | A549   | compound_024h | orf_096h    | Real      | 0.303 | 0.153 |
# | compound_24 vs. orf_48     | A549   | compound_024h | orf_048h    | Real      | 0.289 | 0.122 |
# | compound_48 vs. crispr_144 | A549   | compound_048h | crispr_144h | Real      | 0.283 | 0.193 |
# | compound_48 vs. crispr_96  | A549   | compound_048h | crispr_096h | Real      | 0.297 | 0.201 |
# | compound_48 vs. orf_96     | A549   | compound_048h | orf_096h    | Real      | 0.269 | 0.116 |
# | compound_48 vs. orf_48     | A549   | compound_048h | orf_048h    | Real      | 0.24  | 0.077 |
# | compound_24 vs. crispr_144 | U2OS   | compound_024h | crispr_144h | Real      | 0.225 | 0.123 |
# | compound_24 vs. crispr_96  | U2OS   | compound_024h | crispr_096h | Real      | 0.193 | 0.106 |
# | compound_24 vs. orf_48     | U2OS   | compound_024h | orf_048h    | Real      | 0.314 | 0.149 |
# | compound_24 vs. orf_96     | U2OS   | compound_024h | orf_096h    | Real      | 0.286 | 0.136 |
# | compound_48 vs. crispr_144 | U2OS   | compound_048h | crispr_144h | Real      | 0.249 | 0.154 |
# | compound_48 vs. crispr_96  | U2OS   | compound_048h | crispr_096h | Real      | 0.19  | 0.096 |
# | compound_48 vs. orf_48     | U2OS   | compound_048h | orf_048h    | Real      | 0.319 | 0.16  |
# | compound_48 vs. orf_96     | U2OS   | compound_048h | orf_096h    | Real      | 0.309 | 0.164 |

# %%
print(precision_df[['Description', 'Cell', 'Modality1', 'Modality2', 'Matches', 'mAP', 'mPr']].query('Matches=="Permuted"').to_markdown(index=False))
# Out:
# | Description                | Cell   | Modality1     | Modality2   | Matches   |   mAP |   mPr |
# |:---------------------------|:-------|:--------------|:------------|:----------|------:|------:|
# | compound_24 vs. crispr_144 | A549   | compound_024h | crispr_144h | Permuted  | 0.16  | 0.07  |
# | compound_24 vs. crispr_96  | A549   | compound_024h | crispr_096h | Permuted  | 0.157 | 0.066 |
# | compound_24 vs. orf_96     | A549   | compound_024h | orf_096h    | Permuted  | 0.26  | 0.096 |
# | compound_24 vs. orf_48     | A549   | compound_024h | orf_048h    | Permuted  | 0.178 | 0.036 |
# | compound_48 vs. crispr_144 | A549   | compound_048h | crispr_144h | Permuted  | 0.144 | 0.04  |
# | compound_48 vs. crispr_96  | A549   | compound_048h | crispr_096h | Permuted  | 0.142 | 0.049 |
# | compound_48 vs. orf_96     | A549   | compound_048h | orf_096h    | Permuted  | 0.207 | 0.045 |
# | compound_48 vs. orf_48     | A549   | compound_048h | orf_048h    | Permuted  | 0.205 | 0.059 |
# | compound_24 vs. crispr_144 | U2OS   | compound_024h | crispr_144h | Permuted  | 0.141 | 0.052 |
# | compound_24 vs. crispr_96  | U2OS   | compound_024h | crispr_096h | Permuted  | 0.141 | 0.057 |
# | compound_24 vs. orf_48     | U2OS   | compound_024h | orf_048h    | Permuted  | 0.216 | 0.073 |
# | compound_24 vs. orf_96     | U2OS   | compound_024h | orf_096h    | Permuted  | 0.188 | 0.04  |
# | compound_48 vs. crispr_144 | U2OS   | compound_048h | crispr_144h | Permuted  | 0.158 | 0.063 |
# | compound_48 vs. crispr_96  | U2OS   | compound_048h | crispr_096h | Permuted  | 0.156 | 0.067 |
# | compound_48 vs. orf_48     | U2OS   | compound_048h | orf_048h    | Permuted  | 0.213 | 0.068 |
# | compound_48 vs. orf_96     | U2OS   | compound_048h | orf_096h    | Permuted  | 0.184 | 0.044 |

# %%
precision_df['mAP'] = precision_df['mAP'].astype(float)
precision_df['mPr'] = precision_df['mPr'].astype(float)

precision_df = precision_df.sort_values(by=['Cell','Modality1', 'Modality2']).reset_index(drop=True)

# %%
fig = px.bar(precision_df,
             x='Modality2',
             y='mAP',
             color="Matches",
             barmode="overlay",
             facet_col='Modality1',
             facet_row='Cell')
fig.update_layout(title='mAP - Chemical perturbation vs. genetic perturbation matching',
                  xaxis1=dict(title='Genetic perturbation'),
                  xaxis2=dict(title='Genetic perturbation'),
                  yaxis1=dict(title='mAP'),
                  yaxis3=dict(title='mAP'))
fig.show("png")
fig.write_image(f'figures/17.mAP_matching.png', width=640, height=480, scale=2)

# %%
fig = px.bar(precision_df,
             x='Modality2',
             y='mPr',
             color="Matches",
             barmode="overlay",
             facet_col='Modality1',
             facet_row='Cell')
fig.update_layout(title='mP@r - Chemical perturbation vs. genetic perturbation matching',
                  xaxis1=dict(title='Genetic perturbation'),
                  xaxis2=dict(title='Genetic perturbation'),
                  yaxis1=dict(title='mP@r'),
                  yaxis3=dict(title='mP@r'))
fig.show("png")
fig.write_image(f'figures/17.mPr_matching.png', width=640, height=480, scale=2)

# %%
fig = px.line(all_percent_perturbation_df,
              x='threshold',
              y='percent_perturbations',
              color='Modality2',
              facet_row='Cell',
              facet_col='Modality1')
fig.update_layout(title='Percent perturbations vs. precision@r threshold',
                  xaxis1=dict(title='p@r threshold'),
                  xaxis2=dict(title='p@r threshold'),
                  yaxis1=dict(title='Percent perturbations'),
                  yaxis3=dict(title='Percent perturbations'))
fig.show("png")
fig.write_image(f'figures/17.percent_perturbation_curves.png', width=640, height=480, scale=2)
