# %%
import warnings

warnings.simplefilter(action="ignore", category=FutureWarning)
import pandas as pd
import utils
import plotly.express as px
import scipy.stats as stats
import numpy as np

# %%
# Constants
color_discrete_map_gp = {"ORF": "rgb(0,158,115)", "CRISPR": "rgb(213,94,0)"}

color_discrete_map_cell = {
    "U2OS": "rgb(86,180,233)",
    "A549": "rgb(204,121,167)",
}

cell_order = ["A549", "U2OS"]
genetic_perturbation_order = ["CRISPR", "ORF"]

locations = {
    "line": {
        0: {
            "x0": -0.30,
            "x1": -0.04,
        },
        1: {
            "x0": 0.04,
            "x1": 0.30,
        },
    },
    "text": {
        0: {
            "x": -0.04,
        },
        1: {
            "x": 0.30,
        },
    },
}

# %% [markdown]
# ### Visualizing the directionality of CRIPSR and ORF matching to compounds
# In this notebook, we calculate the cosine similarities for CRISPR-compound and ORF-compound targeting the same genes, for the CellProfiler features.
#
# All compound, ORF and CRISPR plates from the `2020_11_04_CPJUMP1` batch are read, except for those with cell seeding density other than 1000 (100%) and compound plates with antibiotics (Puromycin/Blasticidin) added. Additional annotations for the compounds are also read.

# %% [markdown]
# Normalized, feature selected compound profiles for replicate plates at the same time point, using the same cell type are merged into a single data frame. Negative control and empty wells are removed before computing the median consensus profiles for all compounds and adding additional target annotations. Similarly, consensus ORF and CRISPR profiles are also computed at the two time point and cell types.
#
# Cosine similarity between the consensus chemical and genetic perturbation profiles are computed for all combinations of time point, within each cell type.

# %%
matching_df = pd.DataFrame()
orf_crispr_matching_df = pd.DataFrame()
feature_to_group_by = "Metadata_broad_sample"
batch = "2020_11_04_CPJUMP1"

experiment_df = (
    pd.read_csv("output/experiment-metadata.tsv", sep="\t")
    .query("Batch==@batch")
    .query("Density==100")
    .query('Antibiotics=="absent"')
)

experiment_df.drop(
    experiment_df[
        (experiment_df.Perturbation == "compound") & (experiment_df.Cell_line == "Cas9")
    ].index,
    inplace=True,
)

target1_metadata = pd.read_csv(
    "input/JUMP-Target-1_compound_metadata_additional_annotations.tsv",
    sep="\t",
    usecols=["broad_sample", "target_list"],
).rename(
    columns={
        "broad_sample": "Metadata_broad_sample",
        "target_list": "Metadata_target_list",
    }
)

# %%
for cell in experiment_df.Cell_type.unique():
    cell_df = experiment_df.query("Cell_type==@cell")
    modality_1_perturbation = "compound"
    modality_1_experiments_df = cell_df.query("Perturbation==@modality_1_perturbation")
    for modality_1_timepoint in modality_1_experiments_df.Time.unique():
        modality_1_timepoint_df = modality_1_experiments_df.query(
            "Time==@modality_1_timepoint"
        )
        modality_1_df = pd.DataFrame()
        for plate in modality_1_timepoint_df.Assay_Plate_Barcode.unique():
            # Read all the plates
            data_df = utils.load_data(
                batch, plate, "normalized_feature_select_negcon_batch.csv.gz"
            ).assign(Metadata_modality=modality_1_perturbation)
            modality_1_df = utils.concat_profiles(modality_1_df, data_df)

        # Remove DMSO and empty wells
        modality_1_df = utils.remove_negcon_and_empty_wells(modality_1_df)

        # Create consensus profiles
        modality_1_consensus_df = utils.consensus(modality_1_df, feature_to_group_by)

        # Adding additional gene annotation metadata
        modality_1_consensus_df = modality_1_consensus_df.merge(
            target1_metadata, on="Metadata_broad_sample", how="left"
        )

        # Expand compound profiles and add new matching_target column
        modality_1_consensus_expanded_df = (
            modality_1_consensus_df.assign(
                Metadata_matching_target=lambda x: x.Metadata_target_list.str.split("|")
            )
            .explode("Metadata_matching_target")
            .reset_index(drop=True)
        )

        all_modality_2_experiments_df = cell_df.query(
            "Perturbation!=@modality_1_perturbation"
        )
        for (
            modality_2_perturbation
        ) in all_modality_2_experiments_df.Perturbation.unique():
            modality_2_experiments_df = all_modality_2_experiments_df.query(
                "Perturbation==@modality_2_perturbation"
            )
            for modality_2_timepoint in modality_2_experiments_df.Time.unique():
                modality_2_timepoint_df = modality_2_experiments_df.query(
                    "Time==@modality_2_timepoint"
                )

                modality_2_df = pd.DataFrame()
                for plate in modality_2_timepoint_df.Assay_Plate_Barcode.unique():
                    data_df = (
                        utils.load_data(
                            batch,
                            plate,
                            "normalized_feature_select_negcon_batch.csv.gz",
                        )
                        .assign(Metadata_modality=modality_2_perturbation)
                        .assign(Metadata_matching_target=lambda x: x.Metadata_gene)
                    )
                    modality_2_df = utils.concat_profiles(modality_2_df, data_df)

                # Remove negcon and empty wells
                modality_2_df = utils.remove_negcon_and_empty_wells(modality_2_df)

                # Create consensus profiles (Replicates and sister guides are collapsed)
                modality_2_consensus_df = utils.consensus(
                    modality_2_df, "Metadata_matching_target"
                )

                # Filter out genes that are not perturbed by ORFs or CRISPRs
                perturbed_genes = list(
                    set(modality_2_consensus_df.Metadata_matching_target)
                )
                modality_1_consensus_expanded_filtered_df = (
                    modality_1_consensus_expanded_df.query(
                        "Metadata_matching_target==@perturbed_genes"
                    ).reset_index(drop=True)
                )

                # Calculate gene-compound matching mAP
                description = f"{modality_1_perturbation}_{cell}_{utils.time_point(modality_1_perturbation, modality_1_timepoint)}-{modality_2_perturbation}_{cell}_{utils.time_point(modality_2_perturbation, modality_2_timepoint)}"
                print(f"Computing {description} matching")
                precision = utils.PrecisionScores(
                    modality_1_consensus_expanded_filtered_df,
                    modality_2_consensus_df,
                    "Metadata_matching_target",
                    "matching",
                    "Metadata_broad_sample",
                )

                corr_unstacked = (
                    precision.corr.unstack()
                    .reset_index()
                    .rename(columns={0: "cosine_sim"})
                    .merge(
                        precision.map2[
                            ["Metadata_sample_id", "Metadata_matching_target"]
                        ],
                        left_on="level_0",
                        right_on="Metadata_sample_id",
                        how="left",
                    )
                    .drop(["Metadata_sample_id"], axis=1)
                    .merge(
                        precision.map1[["Metadata_sample_id", "Metadata_broad_sample"]],
                        left_on="level_1",
                        right_on="Metadata_sample_id",
                        how="left",
                    )
                    .drop(["Metadata_sample_id"], axis=1)
                )

                truth_unstacked = (
                    precision.truth_matrix.unstack()
                    .reset_index()
                    .rename(columns={0: "same_target"})
                )

                corr_truth = (
                    corr_unstacked.merge(
                        truth_unstacked, on=["level_0", "level_1"], how="inner"
                    )
                    .assign(Modality1=f"{modality_1_perturbation}")
                    .assign(Genetic_Perturbation=f"{modality_2_perturbation}")
                    .assign(Cell=cell)
                    .assign(
                        Modality_1_timepoint=utils.time_point(
                            modality_1_perturbation, modality_1_timepoint
                        )
                    )
                    .assign(
                        Modality_2_timepoint=utils.time_point(
                            modality_2_perturbation, modality_2_timepoint
                        )
                    )
                )

                matching_df = utils.concat_profiles(matching_df, corr_truth)
# Out:
# Computing compound_A549_short-crispr_A549_long matching
# Computing compound_A549_short-crispr_A549_short matching
# Computing compound_A549_short-orf_A549_long matching
# Computing compound_A549_short-orf_A549_short matching
# Computing compound_A549_long-crispr_A549_long matching
# Computing compound_A549_long-crispr_A549_short matching
# Computing compound_A549_long-orf_A549_long matching
# Computing compound_A549_long-orf_A549_short matching
# Computing compound_U2OS_short-crispr_U2OS_long matching
# Computing compound_U2OS_short-crispr_U2OS_short matching
# Computing compound_U2OS_short-orf_U2OS_short matching
# Computing compound_U2OS_short-orf_U2OS_long matching
# Computing compound_U2OS_long-crispr_U2OS_long matching
# Computing compound_U2OS_long-crispr_U2OS_short matching
# Computing compound_U2OS_long-orf_U2OS_short matching
# Computing compound_U2OS_long-orf_U2OS_long matching

# %%
matching_df = matching_df.replace(
    {"compound": "Compound", "crispr": "CRISPR", "orf": "ORF"}
)

# %%
cols = [
    "Cell",
    "Genetic_Perturbation",
    "Modality_1_timepoint",
    "Modality_2_timepoint",
    "cosine_sim",
]

(matching_df.query("same_target==True").sort_values(by=cols))[
    cols + ["Metadata_broad_sample", "Metadata_matching_target"]
].to_csv("output/compound_genetic_perturbation_cosine_similarity.csv", index=False)

# %% [markdown]
# Box plots are plotted for CRISPR and ORF cosine similarities to compound in the two cell types, separately. The 5th and 95th percentile thersholds of the respective null distributions are shown.

# %%
matching_df.rename(columns={"same_target": "Gene_Target"}, inplace=True)
matching_df.replace(True, "Same", inplace=True)
matching_df.replace(False, "Different", inplace=True)

# %% [markdown]
# Calculate the 5th and 95th percentile thresholds of the nulls. Also calculate the percent and number of matching pairs in the signal distribution, beyond the threshold.

# %%
threshold_percent = pd.DataFrame()

for cell in matching_df.Cell.unique():
    for genetic_perturbation in matching_df.Genetic_Perturbation.unique():
        cell_gp_df = matching_df.query(
            "Cell==@cell and Genetic_Perturbation==@genetic_perturbation"
        ).reset_index(drop=True)
        signal_df = cell_gp_df.query('Gene_Target=="Same"').reset_index(drop=True)
        null_df = cell_gp_df.query('Gene_Target=="Different"').reset_index(drop=True)
        fifth_percentile = null_df.cosine_sim.quantile(0.05)
        ninetyfifth_percentile = null_df.cosine_sim.quantile(0.95)
        percent_fifth_percentile = len(
            signal_df.query("cosine_sim<=@fifth_percentile")
        ) / len(signal_df)
        percent_ninetyfifth_percentile = len(
            signal_df.query("cosine_sim>=@ninetyfifth_percentile")
        ) / len(signal_df)
        n_fifth_percentile = len(signal_df.query("cosine_sim<=@fifth_percentile"))
        n_ninetyfifth_percentile = len(
            signal_df.query("cosine_sim>=@ninetyfifth_percentile")
        )
        n = len(signal_df)

        threshold_percent = pd.concat(
            [
                threshold_percent,
                pd.DataFrame(
                    {
                        "cell": cell,
                        "genetic_perturbation": genetic_perturbation,
                        "fifth_percentile": fifth_percentile,
                        "ninetyfifth_percentile": ninetyfifth_percentile,
                        "percent_fifth_percentile": percent_fifth_percentile,
                        "percent_ninetyfifth_percentile": percent_ninetyfifth_percentile,
                        "n_fifth_percentile": n_fifth_percentile,
                        "n_ninetyfifth_percentile": n_ninetyfifth_percentile,
                        "n": n,
                    },
                    index=[0],
                ),
            ],
            ignore_index=True,
        )

# %% [markdown]
# Print the number of points in each distribution

# %%
print(threshold_percent[['cell', 'genetic_perturbation', 'n']].to_markdown(index=False))
# Out:
# | cell   | genetic_perturbation   |    n |
# |:-------|:-----------------------|-----:|
# | A549   | CRISPR                 | 1864 |
# | A549   | ORF                    | 1864 |
# | U2OS   | CRISPR                 | 1864 |
# | U2OS   | ORF                    | 1864 |

# %% [markdown]
# Create violin plots of the signal distributions that show the null threshold

# %%
fig = px.violin(
    matching_df.query("Gene_Target=='Same'"),
    y="cosine_sim",
    color="Genetic_Perturbation",
    color_discrete_map=color_discrete_map_gp,
    facet_col="Cell",
    category_orders={
        "Cell": cell_order,
        "Genetic_Perturbation": genetic_perturbation_order,
    },
    box=True,
)

fig.update_layout(
    title="Compound-genetic perturbation similarity",
    xaxis1=dict(title="", linecolor="#000000"),
    xaxis2=dict(title="", linecolor="#000000"),
    yaxis1=dict(title="Cosine similarity", linecolor="#000000", tickfont=dict(size=13)),
    yaxis2=dict(linecolor="#000000"),
    font=dict(size=15, color="black"),
    paper_bgcolor="rgba(0,0,0,0)",
    plot_bgcolor="rgba(0,0,0,0)",
    legend=dict(x=0.335, y=1, bgcolor="white", font=dict(size=13)),
)

# Add null threshold lines and percent values to the plot

for i, row in threshold_percent.iterrows():
    fig = utils.add_lines_to_violin_plots(
        fig,
        row,
        locations,
        genetic_perturbation_order,
        "genetic_perturbation",
        5,
        0,
        cell_order.index(row["cell"]) + 1,
    )
    fig = utils.add_lines_to_violin_plots(
        fig,
        row,
        locations,
        genetic_perturbation_order,
        "genetic_perturbation",
        95,
        0,
        cell_order.index(row["cell"]) + 1,
    )
    fig = utils.add_text_to_violin_plots(
        fig,
        row,
        locations,
        genetic_perturbation_order,
        "genetic_perturbation",
        5,
        0,
        cell_order.index(row["cell"]) + 1,
    )
    fig = utils.add_text_to_violin_plots(
        fig,
        row,
        locations,
        genetic_perturbation_order,
        "genetic_perturbation",
        95,
        0,
        cell_order.index(row["cell"]) + 1,
    )

# Add horizontal line at 0 for each subplot

for i in range(matching_df.query("Gene_Target=='Same'").Cell.nunique()):
    fig.add_shape(
        type="line",
        x0=-0.5,
        y0=0,
        x1=0.5,
        y1=0,
        line=dict(color="grey", width=1, dash="dash"),
        row=0,
        col=i,
    )

fig.show("png")
fig.write_image("figures/4.cosine_similarities.png", width=640, height=480, scale=2)
fig.write_image("figures/for_paper/4.cosine_similarities.svg", width=640, height=480, scale=2)

# %% [markdown]
# Fisher's test is used to test for enrichment of the signal distribution beyond the null threshold in both the positive and negative directions.

# %%
for cell in threshold_percent.cell.unique():
    for genetic_perturbation in threshold_percent.query(
        "cell==@cell"
    ).genetic_perturbation.unique():
        df = threshold_percent.query(
            "cell==@cell and genetic_perturbation==@genetic_perturbation"
        ).reset_index(drop=True)
        n_negative_within = df.n[0] - df.n_fifth_percentile[0]
        n_negative_outside = df.n_fifth_percentile[0]
        n_positive_within = df.n[0] - df.n_ninetyfifth_percentile[0]
        n_positive_outside = df.n_ninetyfifth_percentile[0]
        fisher_table = np.array(
            [
                [n_negative_within, n_negative_outside],
                [n_positive_within, n_positive_outside],
            ]
        )
        fishers_exact = stats.fisher_exact(fisher_table)
        threshold_percent.loc[
            (threshold_percent.cell == cell)
            & (threshold_percent.genetic_perturbation == genetic_perturbation),
            "fishers_exact_pvalue",
        ] = utils.convert_pvalue(fishers_exact[1])
        threshold_percent.loc[
            (threshold_percent.cell == cell)
            & (threshold_percent.genetic_perturbation == genetic_perturbation),
            "fishers_exact_statistic",
        ] = fishers_exact[0]

# %%
print(
    threshold_percent[
        [
            "cell",
            "genetic_perturbation",
            "fishers_exact_statistic",
            "fishers_exact_pvalue",
        ]
    ].to_markdown(index=False)
)

threshold_percent[
    ["cell", "genetic_perturbation", "fishers_exact_statistic", "fishers_exact_pvalue"]
].to_csv("output/cosine_similarities_threshold_pvalue.csv", index=False)
# Out:
# | cell   | genetic_perturbation   |   fishers_exact_statistic | fishers_exact_pvalue   |
# |:-------|:-----------------------|--------------------------:|:-----------------------|
# | A549   | CRISPR                 |                   2.03487 | <0.05                  |
# | A549   | ORF                    |                   2.19404 | <0.05                  |
# | U2OS   | CRISPR                 |                   2.81489 | <0.05                  |
# | U2OS   | ORF                    |                   2.63868 | <0.05                  |

# %% [markdown]
# ### Visualize the cosine similarity between ORF and CRISPR profiles
# We calculate the cosine similarity between the following pairs of ORF and CRISPR profiles
#
# - A549
#     - ORF short time point - CRISPR short time point
#     - ORF short time point vs. CRISPR long time point
#     - ORF long time point vs. CRISPR short time point
#     - ORF long time point vs. CRISPR long time point
# - U2OS
#     - ORF short time point vs. CRISPR short time point
#     - ORF short time point vs. CRISPR long time point
#     - ORF long time point vs. CRISPR short time point
#     - ORF long time point vs. CRISPR long time point
#
# Cosine similarity between median consensus ORF and CRISPR profiles are computed.

# %%
genetic_perturbation_experiment_df = experiment_df.query('Perturbation!="compound"')

for cell in genetic_perturbation_experiment_df.Cell_type.unique():
    cell_df = genetic_perturbation_experiment_df.query("Cell_type==@cell")
    orf_cell_df = cell_df.query('Perturbation=="orf"')
    for orf_timepoint in orf_cell_df.Time.unique():
        orf_timepoint_df = orf_cell_df.query("Time==@orf_timepoint")
        orf_df = pd.DataFrame()
        for plate in orf_timepoint_df.Assay_Plate_Barcode.unique():
            data_df = utils.load_data(
                batch, plate, "normalized_feature_select_negcon_batch.csv.gz"
            ).assign(Metadata_matching_target=lambda x: x.Metadata_gene)
            orf_df = utils.concat_profiles(orf_df, data_df)

        # Remove DMSO and empty wells
        orf_df = utils.remove_negcon_and_empty_wells(orf_df)

        # Create consensus profiles (Replicates and sister guides are collapsed)
        orf_consensus_df = utils.consensus(orf_df, "Metadata_matching_target")

        crispr_cell_df = cell_df.query('Perturbation=="crispr"')
        for crispr_timepoint in crispr_cell_df.Time.unique():
            crispr_timepoint_df = crispr_cell_df.query("Time==@crispr_timepoint")
            crispr_df = pd.DataFrame()
            for plate in crispr_timepoint_df.Assay_Plate_Barcode.unique():
                data_df = utils.load_data(
                    batch, plate, "normalized_feature_select_negcon_batch.csv.gz"
                ).assign(Metadata_matching_target=lambda x: x.Metadata_gene)
                crispr_df = utils.concat_profiles(crispr_df, data_df)

            # Remove DMSO and empty wells
            crispr_df = utils.remove_negcon_and_empty_wells(crispr_df)

            # Create consensus profiles (Replicates and sister guides are collapsed)
            crispr_consensus_df = utils.consensus(crispr_df, "Metadata_matching_target")

            # Calculate gene-compound matching mAP
            description = f"ORF_{orf_timepoint}-CRISPR_{crispr_timepoint}"
            print(f"Computing {description} matching in {cell}")
            precision = utils.PrecisionScores(
                orf_consensus_df,
                crispr_consensus_df,
                "Metadata_matching_target",
                "matching",
                "Metadata_broad_sample",
            )

            corr_unstacked = (
                precision.corr.unstack()
                .reset_index()
                .rename(columns={0: "cosine_sim"})
                .merge(
                    precision.map2[["Metadata_sample_id", "Metadata_matching_target"]],
                    left_on="level_0",
                    right_on="Metadata_sample_id",
                    how="left",
                )
                .drop(["Metadata_sample_id"], axis=1)
                .merge(
                    precision.map1[["Metadata_sample_id", "Metadata_broad_sample"]],
                    left_on="level_1",
                    right_on="Metadata_sample_id",
                    how="left",
                )
                .drop(["Metadata_sample_id"], axis=1)
            )

            truth_unstacked = (
                precision.truth_matrix.unstack()
                .reset_index()
                .rename(columns={0: "same_target"})
            )

            corr_truth = (
                corr_unstacked.merge(
                    truth_unstacked, on=["level_0", "level_1"], how="inner"
                )
                .assign(Modality1="ORF")
                .assign(ORF_time=orf_timepoint)
                .assign(Modality2="CRISPR")
                .assign(CRISPR_time=crispr_timepoint)
                .assign(Cell=cell)
            )

            orf_crispr_matching_df = utils.concat_profiles(
                orf_crispr_matching_df, corr_truth
            )
# Out:
# Computing ORF_48-CRISPR_144 matching in U2OS
# Computing ORF_48-CRISPR_96 matching in U2OS
# Computing ORF_96-CRISPR_144 matching in U2OS
# Computing ORF_96-CRISPR_96 matching in U2OS
# Computing ORF_96-CRISPR_144 matching in A549
# Computing ORF_96-CRISPR_96 matching in A549
# Computing ORF_48-CRISPR_144 matching in A549
# Computing ORF_48-CRISPR_96 matching in A549

# %% [markdown]
# Boxplot of ORF-CRISPR cosine similarity is plotted for each cell type separately. The time points are collapsed.

# %%
orf_crispr_matching_df.rename(columns={"same_target": "Gene_Target"}, inplace=True)
orf_crispr_matching_df.replace(True, "Same", inplace=True)
orf_crispr_matching_df.replace(False, "Different", inplace=True)

# %% [markdown]
# Calculate the 5th and 95th percentile thresholds of the nulls. Also calculate the percent and number of matching pairs in the signal distribution, beyond the threshold.

# %%
threshold_percent_orf_crispr = pd.DataFrame()

for cell in orf_crispr_matching_df.Cell.unique():
    cell_gp_df = matching_df.query("Cell==@cell").reset_index(drop=True)
    signal_df = cell_gp_df.query('Gene_Target=="Same"').reset_index(drop=True)
    null_df = cell_gp_df.query('Gene_Target=="Different"').reset_index(drop=True)
    fifth_percentile = null_df.cosine_sim.quantile(0.05)
    ninetyfifth_percentile = null_df.cosine_sim.quantile(0.95)
    percent_fifth_percentile = len(
        signal_df.query("cosine_sim<=@fifth_percentile")
    ) / len(signal_df)
    percent_ninetyfifth_percentile = len(
        signal_df.query("cosine_sim>=@ninetyfifth_percentile")
    ) / len(signal_df)
    n_fifth_percentile = len(signal_df.query("cosine_sim<=@fifth_percentile"))
    n_ninetyfifth_percentile = len(
        signal_df.query("cosine_sim>=@ninetyfifth_percentile")
    )
    n = len(signal_df)

    threshold_percent_orf_crispr = pd.concat(
        [
            threshold_percent_orf_crispr,
            pd.DataFrame(
                {
                    "cell": cell,
                    "fifth_percentile": fifth_percentile,
                    "ninetyfifth_percentile": ninetyfifth_percentile,
                    "percent_fifth_percentile": percent_fifth_percentile,
                    "percent_ninetyfifth_percentile": percent_ninetyfifth_percentile,
                    "n_fifth_percentile": n_fifth_percentile,
                    "n_ninetyfifth_percentile": n_ninetyfifth_percentile,
                    "n": n,
                },
                index=[0],
            ),
        ],
        ignore_index=True,
    )

# %% [markdown]
# Print the number of points in each distribution

# %%
print(threshold_percent_orf_crispr[['cell', 'n']].to_markdown(index=False))
# Out:
# | cell   |    n |
# |:-------|-----:|
# | U2OS   | 3728 |
# | A549   | 3728 |

# %% [markdown]
# Create violin plots of the signal distributions that show the null threshold

# %%
fig = px.violin(
    orf_crispr_matching_df.query("Gene_Target=='Same'"),
    y="cosine_sim",
    color="Cell",
    category_orders={"Cell": cell_order},
    color_discrete_map=color_discrete_map_cell,
    box=True,
)
fig.update_layout(
    title="ORF-CRISPR similarity",
    xaxis1=dict(linecolor="#000000", tickfont=dict(size=13)),
    xaxis2=dict(linecolor="#000000", tickfont=dict(size=13)),
    yaxis1=dict(title="Cosine Similarity", linecolor="#000000", tickfont=dict(size=13)),
    yaxis2=dict(linecolor="#000000"),
    font=dict(size=15, color="black"),
    paper_bgcolor="rgba(0,0,0,0)",
    plot_bgcolor="rgba(0,0,0,0)",
    legend=dict(x=0.8, y=1, bgcolor="white"),
)

# Add null threshold lines and percent values to the plot

for i, row in threshold_percent_orf_crispr.iterrows():
    fig = utils.add_lines_to_violin_plots(
        fig, row, locations, cell_order, "cell", 5, 0, 1
    )
    fig = utils.add_lines_to_violin_plots(
        fig, row, locations, cell_order, "cell", 95, 0, 1
    )
    fig = utils.add_text_to_violin_plots(
        fig, row, locations, cell_order, "cell", 5, 0, 1
    )
    fig = utils.add_text_to_violin_plots(
        fig, row, locations, cell_order, "cell", 95, 0, 1
    )

# Add horizontal line at 0

fig.add_shape(
    type="line",
    x0=-0.5,
    y0=0,
    x1=0.5,
    y1=0,
    line=dict(color="grey", width=1, dash="dash"),
)


fig.show("png")
fig.write_image(
    "figures/4.orf_crispr_cosine_similarities.png", width=640, height=480, scale=2
)
fig.write_image("figures/for_paper/4.orf_crispr_cosine_similarities.svg", width=640, height=480, scale=2)

# %% [markdown]
# Fisher's test

# %%
for cell in threshold_percent_orf_crispr.cell.unique():
    df = threshold_percent_orf_crispr.query("cell==@cell").reset_index(drop=True)
    n_negative_within = df.n[0] - df.n_fifth_percentile[0]
    n_negative_outside = df.n_fifth_percentile[0]
    n_positive_within = df.n[0] - df.n_ninetyfifth_percentile[0]
    n_positive_outside = df.n_ninetyfifth_percentile[0]
    fisher_table = np.array(
        [
            [n_negative_within, n_negative_outside],
            [n_positive_within, n_positive_outside],
        ]
    )
    fishers_exact = stats.fisher_exact(fisher_table)
    threshold_percent_orf_crispr.loc[
        (threshold_percent_orf_crispr.cell == cell), "fishers_exact_pvalue"
    ] = utils.convert_pvalue(fishers_exact[1])
    threshold_percent_orf_crispr.loc[
        (threshold_percent_orf_crispr.cell == cell), "fishers_exact_statistic"
    ] = fishers_exact[0]

# %%
print(
    threshold_percent_orf_crispr[
        ["cell", "fishers_exact_statistic", "fishers_exact_pvalue"]
    ].to_markdown(index=False)
)

threshold_percent_orf_crispr[
    ["cell", "fishers_exact_statistic", "fishers_exact_pvalue"]
].to_csv("output/cosine_similarities_orf_crispr_threshold_pvalue.csv", index=False)
# Out:
# | cell   |   fishers_exact_statistic | fishers_exact_pvalue   |
# |:-------|--------------------------:|:-----------------------|
# | U2OS   |                   2.64156 | <0.05                  |
# | A549   |                   2.19389 | <0.05                  |
