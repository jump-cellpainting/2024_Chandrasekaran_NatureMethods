# %%
import pandas as pd
import plotly.express as px
import numpy as np
import re

color_discrete_map = {"n": "rgb(0,114,178)"}

# %% [markdown]
# ## Calculate the number of targets per compound and the number of compounds per target class.

# %%
batch = "2020_11_04_CPJUMP1"

target1_metadata = (
    pd.read_csv(
        "input/JUMP-Target-1_compound_metadata_additional_annotations.tsv",
        sep="\t",
        usecols=["broad_sample", "target_list"],
    )
    .rename(
        columns={
            "broad_sample": "Metadata_broad_sample",
            "target_list": "Metadata_target_list",
        }
    )
    .assign(Metadata_target=lambda x: x.Metadata_target_list.str.split("|"))
    .explode("Metadata_target")
    .dropna()
    .reset_index(drop=True)
)

crispr_metadata = pd.read_csv(
    "../metadata/external_metadata/JUMP-Target-1_crispr_metadata.tsv", sep="\t"
)
genes = crispr_metadata = list(set(crispr_metadata.gene))

# Filter out rows that don't correspond to genes in the CRISPR experiment
target1_metadata = target1_metadata.query("Metadata_target==@genes").reset_index(
    drop=True
)

# Group similar genes together
target1_metadata["Metadata_target_trimmed"] = [
    x[0 : re.search(r"\d", x).start()] if re.search(r"\d", x) else x
    for x in target1_metadata.Metadata_target
]

# %% [markdown]
# ### Number of targets per compound

# %%
n_targets = (
    target1_metadata.groupby("Metadata_broad_sample")
    .Metadata_target.apply(lambda x: len(x))
    .reset_index()
)
targets_df = (
    n_targets.Metadata_target.value_counts()
    .reset_index()
    .rename(columns={"index": "n", "Metadata_target": "n_target"})
    .assign(color="n")
)

# %%
fig = px.bar(
    targets_df,
    x="n",
    y="n_target",
    text="n_target",
    color="color",
    color_discrete_map=color_discrete_map,
)
fig.update_traces(textposition="outside")
fig.update_layout(
    title="Number of targets per compound",
    xaxis=dict(title="Number of targets", linecolor="#000000", tickmode="linear"),
    yaxis=dict(title="Number of compounds", linecolor="#000000"),
    paper_bgcolor="rgba(0,0,0,0)",
    plot_bgcolor="rgba(0,0,0,0)",
    showlegend=False,
)
fig.show("png")
fig.write_image("figures/5.number_of_targets.png", width=640, height=480, scale=2)
fig.write_image("figures/for_paper/5.number_of_targets.svg", width=640, height=480, scale=2)

# %% [markdown]
# ### Number of compounds per target class

# %%
n_compounds = (
    target1_metadata.groupby("Metadata_target")
    .Metadata_broad_sample.apply(lambda x: len(x))
    .reset_index()
)
compounds_df = (
    n_compounds.Metadata_broad_sample.value_counts()
    .reset_index()
    .rename(columns={"index": "n", "Metadata_broad_sample": "n_compounds"})
    .assign(color="n")
)

# %%
fig = px.bar(
    compounds_df,
    x="n",
    y="n_compounds",
    text="n_compounds",
    color="color",
    color_discrete_map=color_discrete_map,
)
fig.update_traces(textposition="outside")
fig.update_layout(
    title="Number of compounds per target",
    xaxis=dict(title="Number of compounds", linecolor="#000000", tickmode="linear"),
    yaxis=dict(title="Number of targets", linecolor="#000000"),
    paper_bgcolor="rgba(0,0,0,0)",
    plot_bgcolor="rgba(0,0,0,0)",
    showlegend=False,
)
fig.show("png")
fig.write_image("figures/5.number_of_compounds.png", width=640, height=480, scale=2)
fig.write_image("figures/for_paper/5.number_of_compounds.svg", width=640, height=480, scale=2)

# %% [markdown]
# ### Number of compounds of gene familes targeted per compound

# %%
n_targets_trimmed = (
    target1_metadata.groupby("Metadata_broad_sample")
    .Metadata_target_trimmed.apply(lambda x: len(list(set(x))))
    .reset_index()
)
targets_trimmed_df = (
    n_targets_trimmed.Metadata_target_trimmed.value_counts()
    .reset_index()
    .rename(columns={"index": "n", "Metadata_target_trimmed": "n_target_trimmed"})
    .assign(color="n")
)

# %%
fig = px.bar(
    targets_trimmed_df,
    x="n",
    y="n_target_trimmed",
    text="n_target_trimmed",
    color="color",
    color_discrete_map=color_discrete_map,
)
fig.update_traces(textposition="outside")
fig.update_layout(
    title="Number of targets (grouped) per compound",
    xaxis=dict(title="Number of targets", linecolor="#000000", tickmode="linear"),
    yaxis=dict(title="Number of compounds", linecolor="#000000"),
    paper_bgcolor="rgba(0,0,0,0)",
    plot_bgcolor="rgba(0,0,0,0)",
    showlegend=False,
)
fig.show("png")
fig.write_image(
    "figures/5.number_of_targets_trimmed.png", width=640, height=480, scale=2
)
fig.write_image(
    "figures/for_paper/5.number_of_targets_trimmed.svg", width=640, height=480, scale=2
)
