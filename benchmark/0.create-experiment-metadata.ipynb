# %%
import pandas as pd
import os
import glob
import numpy as np

# %%
col_order = ['Batch', 'Plate_Map_Name','Assay_Plate_Barcode', 'Perturbation', 'Cell_type', 'Time', 'Density', 'Antibiotics', 'Cell_line', 'Time_delay', 'Times_imaged', 'Anomaly','Number_of_images']

antibiotics_df = pd.DataFrame({'Assay_Plate_Barcode': ['BR00118049','BR00117002', 'BR00117001'], 'Antibiotics': ['Blasticidin', 'Puromycin', 'Puromycin']})

density_df = pd.DataFrame({'Assay_Plate_Barcode': ['BR00117054', 'BR00117055', 'BR00117008', 'BR00117009'], 'Density': ['120', '120', '80', '80']})

cell_line_df = pd.DataFrame({'Assay_Plate_Barcode': ['BR00117052', 'BR00117053', 'BR00117050', 'BR00117051'], 'Cell_line': ['Cas9', 'Cas9', 'Cas9', 'Cas9']})

anomalous_plates = {
    'Phalloidin': ['BR00118050',
                   'BR00117006',
                   'BR00118049',
                   'BR00118039',
                   'BR00118040',
                   'BR00118041',
                   'BR00118042',
                   'BR00118043',
                   'BR00118044',
                   'BR00118045',
                   'BR00118046',
                   'BR00118047',
                   'BR00118048'],
    'WGA': ['BR00116997',
            'BR00116998',
            'BR00116999',
            'BR00116996',
            'BR00116991',
            'BR00116992',
            'BR00116993',
            'BR00116994',
            'BR00116995',
            'BR00117024',
            'BR00117025',
            'BR00117026'],
    'Mitotracker': ['BR00117013',
                    'BR00117010']
}

# %%
# Read barcode_platemap files
path = os.path.join('../metadata/platemaps/*/barcode_platemap.csv')
files = glob.glob(path)
df = pd.concat(
    (
        (
            pd.read_csv(_)
            .assign(Batch=_.split('/')[3])
            .assign(Anomaly='none')
            .assign(Time_delay='Day0')
            .assign(Times_imaged='1')
            .assign(Time='0')
        ) for _ in files),
    ignore_index=True
)

# Read number of images csv
path = os.path.join('input/2020*.csv')
files = glob.glob(path)
images_df = pd.concat((pd.read_csv(_) for _ in files), ignore_index=True)

df['Perturbation'] = np.asarray(list(df.Plate_Map_Name.str.split('_').values))[:,1]

# %%
# Add antibiotics column
df = df.merge(antibiotics_df, on='Assay_Plate_Barcode', how='left')
df.Antibiotics.replace(np.nan, 'absent', inplace=True)
df.query('Antibiotics!="absent"').head()
# Out:
#    Assay_Plate_Barcode                 Plate_Map_Name               Batch  \
# 49          BR00118049     JUMP-Target-1_orf_platemap  2020_11_04_CPJUMP1
# 69          BR00117002  JUMP-Target-1_crispr_platemap  2020_11_04_CPJUMP1
# 70          BR00117001  JUMP-Target-1_crispr_platemap  2020_11_04_CPJUMP1
#
#    Anomaly Time_delay Times_imaged Time Perturbation  Antibiotics
# 49    none       Day0            1    0          orf  Blasticidin
# 69    none       Day0            1    0       crispr    Puromycin
# 70    none       Day0            1    0       crispr    Puromycin

# %%
# Add density column
df = df.merge(density_df, on='Assay_Plate_Barcode', how='left')
df.Density.replace(np.nan, '100', inplace=True)
df.query('Density!="100"').head()
# Out:
#    Assay_Plate_Barcode                   Plate_Map_Name               Batch  \
# 91          BR00117054  JUMP-Target-1_compound_platemap  2020_11_04_CPJUMP1
# 92          BR00117055  JUMP-Target-1_compound_platemap  2020_11_04_CPJUMP1
# 93          BR00117008  JUMP-Target-1_compound_platemap  2020_11_04_CPJUMP1
# 94          BR00117009  JUMP-Target-1_compound_platemap  2020_11_04_CPJUMP1
#
#    Anomaly Time_delay Times_imaged Time Perturbation Antibiotics Density
# 91    none       Day0            1    0     compound      absent     120
# 92    none       Day0            1    0     compound      absent     120
# 93    none       Day0            1    0     compound      absent      80
# 94    none       Day0            1    0     compound      absent      80

# %%
# Add Cell line column
df = df.merge(cell_line_df, on='Assay_Plate_Barcode', how='left')
df.loc[df.Perturbation=='crispr','Cell_line'] = 'Cas9'
df.Cell_line.replace(np.nan, 'Parental', inplace=True)
df.query('Cell_line=="Cas9"').head(50)
# Out:
#     Assay_Plate_Barcode                   Plate_Map_Name  \
# 57           BR00118041    JUMP-Target-1_crispr_platemap
# 58           BR00118042    JUMP-Target-1_crispr_platemap
# 59           BR00118043    JUMP-Target-1_crispr_platemap
# 60           BR00118044    JUMP-Target-1_crispr_platemap
# 61           BR00118045    JUMP-Target-1_crispr_platemap
# 62           BR00118046    JUMP-Target-1_crispr_platemap
# 63           BR00118047    JUMP-Target-1_crispr_platemap
# 64           BR00118048    JUMP-Target-1_crispr_platemap
# 65           BR00117003    JUMP-Target-1_crispr_platemap
# 66           BR00117004    JUMP-Target-1_crispr_platemap
# 67           BR00117005    JUMP-Target-1_crispr_platemap
# 68           BR00117000    JUMP-Target-1_crispr_platemap
# 69           BR00117002    JUMP-Target-1_crispr_platemap
# 70           BR00117001    JUMP-Target-1_crispr_platemap
# 71           BR00116997    JUMP-Target-1_crispr_platemap
# 72           BR00116998    JUMP-Target-1_crispr_platemap
# 73           BR00116999    JUMP-Target-1_crispr_platemap
# 74           BR00116996    JUMP-Target-1_crispr_platemap
# 95           BR00117052  JUMP-Target-1_compound_platemap
# 96           BR00117053  JUMP-Target-1_compound_platemap
# 97           BR00117050  JUMP-Target-1_compound_platemap
# 98           BR00117051  JUMP-Target-1_compound_platemap
# 101          BR00116997    JUMP-Target-1_crispr_platemap
# 102          BR00116998    JUMP-Target-1_crispr_platemap
# 103          BR00116999    JUMP-Target-1_crispr_platemap
# 104          BR00116996    JUMP-Target-1_crispr_platemap
#
#                      Batch Anomaly Time_delay Times_imaged Time Perturbation  \
# 57      2020_11_04_CPJUMP1    none       Day0            1    0       crispr
# 58      2020_11_04_CPJUMP1    none       Day0            1    0       crispr
# 59      2020_11_04_CPJUMP1    none       Day0            1    0       crispr
# 60      2020_11_04_CPJUMP1    none       Day0            1    0       crispr
# 61      2020_11_04_CPJUMP1    none       Day0            1    0       crispr
# 62      2020_11_04_CPJUMP1    none       Day0            1    0       crispr
# 63      2020_11_04_CPJUMP1    none       Day0            1    0       crispr
# 64      2020_11_04_CPJUMP1    none       Day0            1    0       crispr
# 65      2020_11_04_CPJUMP1    none       Day0            1    0       crispr
# 66      2020_11_04_CPJUMP1    none       Day0            1    0       crispr
# 67      2020_11_04_CPJUMP1    none       Day0            1    0       crispr
# 68      2020_11_04_CPJUMP1    none       Day0            1    0       crispr
# 69      2020_11_04_CPJUMP1    none       Day0            1    0       crispr
# 70      2020_11_04_CPJUMP1    none       Day0            1    0       crispr
# 71      2020_11_04_CPJUMP1    none       Day0            1    0       crispr
# 72      2020_11_04_CPJUMP1    none       Day0            1    0       crispr
# 73      2020_11_04_CPJUMP1    none       Day0            1    0       crispr
# 74      2020_11_04_CPJUMP1    none       Day0            1    0       crispr
# 95      2020_11_04_CPJUMP1    none       Day0            1    0     compound
# 96      2020_11_04_CPJUMP1    none       Day0            1    0     compound
# 97      2020_11_04_CPJUMP1    none       Day0            1    0     compound
# 98      2020_11_04_CPJUMP1    none       Day0            1    0     compound
# 101  2020_11_04_CPJUMP1_DL    none       Day0            1    0       crispr
# 102  2020_11_04_CPJUMP1_DL    none       Day0            1    0       crispr
# 103  2020_11_04_CPJUMP1_DL    none       Day0            1    0       crispr
# 104  2020_11_04_CPJUMP1_DL    none       Day0            1    0       crispr
#
#     Antibiotics Density Cell_line
# 57       absent     100      Cas9
# 58       absent     100      Cas9
# 59       absent     100      Cas9
# 60       absent     100      Cas9
# 61       absent     100      Cas9
# 62       absent     100      Cas9
# 63       absent     100      Cas9
# 64       absent     100      Cas9
# 65       absent     100      Cas9
# 66       absent     100      Cas9
# 67       absent     100      Cas9
# 68       absent     100      Cas9
# 69    Puromycin     100      Cas9
# 70    Puromycin     100      Cas9
# 71       absent     100      Cas9
# 72       absent     100      Cas9
# 73       absent     100      Cas9
# 74       absent     100      Cas9
# 95       absent     100      Cas9
# 96       absent     100      Cas9
# 97       absent     100      Cas9
# 98       absent     100      Cas9
# 101      absent     100      Cas9
# 102      absent     100      Cas9
# 103      absent     100      Cas9
# 104      absent     100      Cas9

# %%
# Fill the Time delay column
df.loc[df.Batch.str.contains('Day1'), 'Time_delay'] = 'Day1'
df.loc[df.Batch.str.contains('Day4'), 'Time_delay'] = 'Day4'
df.loc[df.Batch.str.contains('2Weeks'), 'Time_delay'] = 'Week2'
df.loc[df.Batch.str.contains('4Weeks'), 'Time_delay'] = 'Week4'
df.query('Time_delay!="Day0"').head(50)
# Out:
#     Assay_Plate_Barcode              Plate_Map_Name  \
# 24           BR00117006  JUMP-Target-1_orf_platemap
# 25           BR00118050  JUMP-Target-1_orf_platemap
# 26           BR00118039  JUMP-Target-1_orf_platemap
# 27           BR00118040  JUMP-Target-1_orf_platemap
# 28           BR00117020  JUMP-Target-1_orf_platemap
# 29           BR00117021  JUMP-Target-1_orf_platemap
# 30           BR00117022  JUMP-Target-1_orf_platemap
# 31           BR00117023  JUMP-Target-1_orf_platemap
# 32           BR00117006  JUMP-Target-1_orf_platemap
# 33           BR00118050  JUMP-Target-1_orf_platemap
# 34           BR00118039  JUMP-Target-1_orf_platemap
# 35           BR00118040  JUMP-Target-1_orf_platemap
# 36           BR00117020  JUMP-Target-1_orf_platemap
# 37           BR00117021  JUMP-Target-1_orf_platemap
# 38           BR00117022  JUMP-Target-1_orf_platemap
# 39           BR00117023  JUMP-Target-1_orf_platemap
# 40           BR00117006  JUMP-Target-1_orf_platemap
# 41           BR00118050  JUMP-Target-1_orf_platemap
# 42           BR00118039  JUMP-Target-1_orf_platemap
# 43           BR00118040  JUMP-Target-1_orf_platemap
# 44           BR00117020  JUMP-Target-1_orf_platemap
# 45           BR00117021  JUMP-Target-1_orf_platemap
# 46           BR00117022  JUMP-Target-1_orf_platemap
# 47           BR00117023  JUMP-Target-1_orf_platemap
# 109          BR00117006  JUMP-Target-1_orf_platemap
# 110          BR00118050  JUMP-Target-1_orf_platemap
# 111          BR00118039  JUMP-Target-1_orf_platemap
# 112          BR00118040  JUMP-Target-1_orf_platemap
# 113          BR00117020  JUMP-Target-1_orf_platemap
# 114          BR00117021  JUMP-Target-1_orf_platemap
# 115          BR00117022  JUMP-Target-1_orf_platemap
# 116          BR00117023  JUMP-Target-1_orf_platemap
#
#                                   Batch Anomaly Time_delay Times_imaged Time  \
# 24   2020_12_02_CPJUMP1_2WeeksTimePoint    none      Week2            1    0
# 25   2020_12_02_CPJUMP1_2WeeksTimePoint    none      Week2            1    0
# 26   2020_12_02_CPJUMP1_2WeeksTimePoint    none      Week2            1    0
# 27   2020_12_02_CPJUMP1_2WeeksTimePoint    none      Week2            1    0
# 28   2020_12_02_CPJUMP1_2WeeksTimePoint    none      Week2            1    0
# 29   2020_12_02_CPJUMP1_2WeeksTimePoint    none      Week2            1    0
# 30   2020_12_02_CPJUMP1_2WeeksTimePoint    none      Week2            1    0
# 31   2020_12_02_CPJUMP1_2WeeksTimePoint    none      Week2            1    0
# 32             2020_11_19_TimepointDay4    none       Day4            1    0
# 33             2020_11_19_TimepointDay4    none       Day4            1    0
# 34             2020_11_19_TimepointDay4    none       Day4            1    0
# 35             2020_11_19_TimepointDay4    none       Day4            1    0
# 36             2020_11_19_TimepointDay4    none       Day4            1    0
# 37             2020_11_19_TimepointDay4    none       Day4            1    0
# 38             2020_11_19_TimepointDay4    none       Day4            1    0
# 39             2020_11_19_TimepointDay4    none       Day4            1    0
# 40   2020_12_07_CPJUMP1_4WeeksTimePoint    none      Week4            1    0
# 41   2020_12_07_CPJUMP1_4WeeksTimePoint    none      Week4            1    0
# 42   2020_12_07_CPJUMP1_4WeeksTimePoint    none      Week4            1    0
# 43   2020_12_07_CPJUMP1_4WeeksTimePoint    none      Week4            1    0
# 44   2020_12_07_CPJUMP1_4WeeksTimePoint    none      Week4            1    0
# 45   2020_12_07_CPJUMP1_4WeeksTimePoint    none      Week4            1    0
# 46   2020_12_07_CPJUMP1_4WeeksTimePoint    none      Week4            1    0
# 47   2020_12_07_CPJUMP1_4WeeksTimePoint    none      Week4            1    0
# 109    2020_11_18_CPJUMP1_TimepointDay1    none       Day1            1    0
# 110    2020_11_18_CPJUMP1_TimepointDay1    none       Day1            1    0
# 111    2020_11_18_CPJUMP1_TimepointDay1    none       Day1            1    0
# 112    2020_11_18_CPJUMP1_TimepointDay1    none       Day1            1    0
# 113    2020_11_18_CPJUMP1_TimepointDay1    none       Day1            1    0
# 114    2020_11_18_CPJUMP1_TimepointDay1    none       Day1            1    0
# 115    2020_11_18_CPJUMP1_TimepointDay1    none       Day1            1    0
# 116    2020_11_18_CPJUMP1_TimepointDay1    none       Day1            1    0
#
#     Perturbation Antibiotics Density Cell_line
# 24           orf      absent     100  Parental
# 25           orf      absent     100  Parental
# 26           orf      absent     100  Parental
# 27           orf      absent     100  Parental
# 28           orf      absent     100  Parental
# 29           orf      absent     100  Parental
# 30           orf      absent     100  Parental
# 31           orf      absent     100  Parental
# 32           orf      absent     100  Parental
# 33           orf      absent     100  Parental
# 34           orf      absent     100  Parental
# 35           orf      absent     100  Parental
# 36           orf      absent     100  Parental
# 37           orf      absent     100  Parental
# 38           orf      absent     100  Parental
# 39           orf      absent     100  Parental
# 40           orf      absent     100  Parental
# 41           orf      absent     100  Parental
# 42           orf      absent     100  Parental
# 43           orf      absent     100  Parental
# 44           orf      absent     100  Parental
# 45           orf      absent     100  Parental
# 46           orf      absent     100  Parental
# 47           orf      absent     100  Parental
# 109          orf      absent     100  Parental
# 110          orf      absent     100  Parental
# 111          orf      absent     100  Parental
# 112          orf      absent     100  Parental
# 113          orf      absent     100  Parental
# 114          orf      absent     100  Parental
# 115          orf      absent     100  Parental
# 116          orf      absent     100  Parental

# %%
# Fill the Times imaged column
df.loc[df.Assay_Plate_Barcode.str.endswith('A'), 'Times_imaged'] = '2'
df.loc[df.Assay_Plate_Barcode.str.endswith('B'), 'Times_imaged'] = '3'
df.loc[df.Assay_Plate_Barcode.str.endswith('C'), 'Times_imaged'] = '4'
df.loc[df.Assay_Plate_Barcode.str.endswith('D'), 'Times_imaged'] = '5'
df.loc[df.Assay_Plate_Barcode.str.endswith('E'), 'Times_imaged'] = '6'
df.loc[df.Assay_Plate_Barcode.str.endswith('F'), 'Times_imaged'] = '7'

df.loc[df.Time_delay=="Week2", 'Times_imaged'] = '2'
df.loc[df.Time_delay=="Week4", 'Times_imaged'] = '3'

df.query('Times_imaged=="3"').head(50)
# Out:
#    Assay_Plate_Barcode                   Plate_Map_Name  \
# 1          BR00116991B  JUMP-Target-1_compound_platemap
# 7          BR00116992B  JUMP-Target-1_compound_platemap
# 13         BR00116993B  JUMP-Target-1_compound_platemap
# 19         BR00116994B  JUMP-Target-1_compound_platemap
# 40          BR00117006       JUMP-Target-1_orf_platemap
# 41          BR00118050       JUMP-Target-1_orf_platemap
# 42          BR00118039       JUMP-Target-1_orf_platemap
# 43          BR00118040       JUMP-Target-1_orf_platemap
# 44          BR00117020       JUMP-Target-1_orf_platemap
# 45          BR00117021       JUMP-Target-1_orf_platemap
# 46          BR00117022       JUMP-Target-1_orf_platemap
# 47          BR00117023       JUMP-Target-1_orf_platemap
#
#                                  Batch Anomaly Time_delay Times_imaged Time  \
# 1         2020_12_08_CPJUMP1_Bleaching    none       Day0            3    0
# 7         2020_12_08_CPJUMP1_Bleaching    none       Day0            3    0
# 13        2020_12_08_CPJUMP1_Bleaching    none       Day0            3    0
# 19        2020_12_08_CPJUMP1_Bleaching    none       Day0            3    0
# 40  2020_12_07_CPJUMP1_4WeeksTimePoint    none      Week4            3    0
# 41  2020_12_07_CPJUMP1_4WeeksTimePoint    none      Week4            3    0
# 42  2020_12_07_CPJUMP1_4WeeksTimePoint    none      Week4            3    0
# 43  2020_12_07_CPJUMP1_4WeeksTimePoint    none      Week4            3    0
# 44  2020_12_07_CPJUMP1_4WeeksTimePoint    none      Week4            3    0
# 45  2020_12_07_CPJUMP1_4WeeksTimePoint    none      Week4            3    0
# 46  2020_12_07_CPJUMP1_4WeeksTimePoint    none      Week4            3    0
# 47  2020_12_07_CPJUMP1_4WeeksTimePoint    none      Week4            3    0
#
#    Perturbation Antibiotics Density Cell_line
# 1      compound      absent     100  Parental
# 7      compound      absent     100  Parental
# 13     compound      absent     100  Parental
# 19     compound      absent     100  Parental
# 40          orf      absent     100  Parental
# 41          orf      absent     100  Parental
# 42          orf      absent     100  Parental
# 43          orf      absent     100  Parental
# 44          orf      absent     100  Parental
# 45          orf      absent     100  Parental
# 46          orf      absent     100  Parental
# 47          orf      absent     100  Parental

# %%
# Fill anomalies column
for anomaly in anomalous_plates:
    for plate in anomalous_plates[anomaly]:
        df.loc[df.Assay_Plate_Barcode==plate, 'Anomaly'] = anomaly
df.query('Anomaly!="none"').head(50)
# Out:
#     Assay_Plate_Barcode                   Plate_Map_Name  \
# 24           BR00117006       JUMP-Target-1_orf_platemap
# 25           BR00118050       JUMP-Target-1_orf_platemap
# 26           BR00118039       JUMP-Target-1_orf_platemap
# 27           BR00118040       JUMP-Target-1_orf_platemap
# 32           BR00117006       JUMP-Target-1_orf_platemap
# 33           BR00118050       JUMP-Target-1_orf_platemap
# 34           BR00118039       JUMP-Target-1_orf_platemap
# 35           BR00118040       JUMP-Target-1_orf_platemap
# 40           BR00117006       JUMP-Target-1_orf_platemap
# 41           BR00118050       JUMP-Target-1_orf_platemap
# 42           BR00118039       JUMP-Target-1_orf_platemap
# 43           BR00118040       JUMP-Target-1_orf_platemap
# 48           BR00117006       JUMP-Target-1_orf_platemap
# 49           BR00118049       JUMP-Target-1_orf_platemap
# 50           BR00118050       JUMP-Target-1_orf_platemap
# 51           BR00118039       JUMP-Target-1_orf_platemap
# 52           BR00118040       JUMP-Target-1_orf_platemap
# 57           BR00118041    JUMP-Target-1_crispr_platemap
# 58           BR00118042    JUMP-Target-1_crispr_platemap
# 59           BR00118043    JUMP-Target-1_crispr_platemap
# 60           BR00118044    JUMP-Target-1_crispr_platemap
# 61           BR00118045    JUMP-Target-1_crispr_platemap
# 62           BR00118046    JUMP-Target-1_crispr_platemap
# 63           BR00118047    JUMP-Target-1_crispr_platemap
# 64           BR00118048    JUMP-Target-1_crispr_platemap
# 71           BR00116997    JUMP-Target-1_crispr_platemap
# 72           BR00116998    JUMP-Target-1_crispr_platemap
# 73           BR00116999    JUMP-Target-1_crispr_platemap
# 74           BR00116996    JUMP-Target-1_crispr_platemap
# 75           BR00116991  JUMP-Target-1_compound_platemap
# 76           BR00116992  JUMP-Target-1_compound_platemap
# 77           BR00116993  JUMP-Target-1_compound_platemap
# 78           BR00116994  JUMP-Target-1_compound_platemap
# 79           BR00116995  JUMP-Target-1_compound_platemap
# 80           BR00117024  JUMP-Target-1_compound_platemap
# 81           BR00117025  JUMP-Target-1_compound_platemap
# 82           BR00117026  JUMP-Target-1_compound_platemap
# 88           BR00117013  JUMP-Target-1_compound_platemap
# 89           BR00117010  JUMP-Target-1_compound_platemap
# 99           BR00118039       JUMP-Target-1_orf_platemap
# 100          BR00118040       JUMP-Target-1_orf_platemap
# 101          BR00116997    JUMP-Target-1_crispr_platemap
# 102          BR00116998    JUMP-Target-1_crispr_platemap
# 103          BR00116999    JUMP-Target-1_crispr_platemap
# 104          BR00116996    JUMP-Target-1_crispr_platemap
# 106          BR00117013  JUMP-Target-1_compound_platemap
# 107          BR00117010  JUMP-Target-1_compound_platemap
# 109          BR00117006       JUMP-Target-1_orf_platemap
# 110          BR00118050       JUMP-Target-1_orf_platemap
# 111          BR00118039       JUMP-Target-1_orf_platemap
#
#                                   Batch      Anomaly Time_delay Times_imaged  \
# 24   2020_12_02_CPJUMP1_2WeeksTimePoint   Phalloidin      Week2            2
# 25   2020_12_02_CPJUMP1_2WeeksTimePoint   Phalloidin      Week2            2
# 26   2020_12_02_CPJUMP1_2WeeksTimePoint   Phalloidin      Week2            2
# 27   2020_12_02_CPJUMP1_2WeeksTimePoint   Phalloidin      Week2            2
# 32             2020_11_19_TimepointDay4   Phalloidin       Day4            1
# 33             2020_11_19_TimepointDay4   Phalloidin       Day4            1
# 34             2020_11_19_TimepointDay4   Phalloidin       Day4            1
# 35             2020_11_19_TimepointDay4   Phalloidin       Day4            1
# 40   2020_12_07_CPJUMP1_4WeeksTimePoint   Phalloidin      Week4            3
# 41   2020_12_07_CPJUMP1_4WeeksTimePoint   Phalloidin      Week4            3
# 42   2020_12_07_CPJUMP1_4WeeksTimePoint   Phalloidin      Week4            3
# 43   2020_12_07_CPJUMP1_4WeeksTimePoint   Phalloidin      Week4            3
# 48                   2020_11_04_CPJUMP1   Phalloidin       Day0            1
# 49                   2020_11_04_CPJUMP1   Phalloidin       Day0            1
# 50                   2020_11_04_CPJUMP1   Phalloidin       Day0            1
# 51                   2020_11_04_CPJUMP1   Phalloidin       Day0            1
# 52                   2020_11_04_CPJUMP1   Phalloidin       Day0            1
# 57                   2020_11_04_CPJUMP1   Phalloidin       Day0            1
# 58                   2020_11_04_CPJUMP1   Phalloidin       Day0            1
# 59                   2020_11_04_CPJUMP1   Phalloidin       Day0            1
# 60                   2020_11_04_CPJUMP1   Phalloidin       Day0            1
# 61                   2020_11_04_CPJUMP1   Phalloidin       Day0            1
# 62                   2020_11_04_CPJUMP1   Phalloidin       Day0            1
# 63                   2020_11_04_CPJUMP1   Phalloidin       Day0            1
# 64                   2020_11_04_CPJUMP1   Phalloidin       Day0            1
# 71                   2020_11_04_CPJUMP1          WGA       Day0            1
# 72                   2020_11_04_CPJUMP1          WGA       Day0            1
# 73                   2020_11_04_CPJUMP1          WGA       Day0            1
# 74                   2020_11_04_CPJUMP1          WGA       Day0            1
# 75                   2020_11_04_CPJUMP1          WGA       Day0            1
# 76                   2020_11_04_CPJUMP1          WGA       Day0            1
# 77                   2020_11_04_CPJUMP1          WGA       Day0            1
# 78                   2020_11_04_CPJUMP1          WGA       Day0            1
# 79                   2020_11_04_CPJUMP1          WGA       Day0            1
# 80                   2020_11_04_CPJUMP1          WGA       Day0            1
# 81                   2020_11_04_CPJUMP1          WGA       Day0            1
# 82                   2020_11_04_CPJUMP1          WGA       Day0            1
# 88                   2020_11_04_CPJUMP1  Mitotracker       Day0            1
# 89                   2020_11_04_CPJUMP1  Mitotracker       Day0            1
# 99                2020_11_04_CPJUMP1_DL   Phalloidin       Day0            1
# 100               2020_11_04_CPJUMP1_DL   Phalloidin       Day0            1
# 101               2020_11_04_CPJUMP1_DL          WGA       Day0            1
# 102               2020_11_04_CPJUMP1_DL          WGA       Day0            1
# 103               2020_11_04_CPJUMP1_DL          WGA       Day0            1
# 104               2020_11_04_CPJUMP1_DL          WGA       Day0            1
# 106               2020_11_04_CPJUMP1_DL  Mitotracker       Day0            1
# 107               2020_11_04_CPJUMP1_DL  Mitotracker       Day0            1
# 109    2020_11_18_CPJUMP1_TimepointDay1   Phalloidin       Day1            1
# 110    2020_11_18_CPJUMP1_TimepointDay1   Phalloidin       Day1            1
# 111    2020_11_18_CPJUMP1_TimepointDay1   Phalloidin       Day1            1
#
#     Time Perturbation  Antibiotics Density Cell_line
# 24     0          orf       absent     100  Parental
# 25     0          orf       absent     100  Parental
# 26     0          orf       absent     100  Parental
# 27     0          orf       absent     100  Parental
# 32     0          orf       absent     100  Parental
# 33     0          orf       absent     100  Parental
# 34     0          orf       absent     100  Parental
# 35     0          orf       absent     100  Parental
# 40     0          orf       absent     100  Parental
# 41     0          orf       absent     100  Parental
# 42     0          orf       absent     100  Parental
# 43     0          orf       absent     100  Parental
# 48     0          orf       absent     100  Parental
# 49     0          orf  Blasticidin     100  Parental
# 50     0          orf       absent     100  Parental
# 51     0          orf       absent     100  Parental
# 52     0          orf       absent     100  Parental
# 57     0       crispr       absent     100      Cas9
# 58     0       crispr       absent     100      Cas9
# 59     0       crispr       absent     100      Cas9
# 60     0       crispr       absent     100      Cas9
# 61     0       crispr       absent     100      Cas9
# 62     0       crispr       absent     100      Cas9
# 63     0       crispr       absent     100      Cas9
# 64     0       crispr       absent     100      Cas9
# 71     0       crispr       absent     100      Cas9
# 72     0       crispr       absent     100      Cas9
# 73     0       crispr       absent     100      Cas9
# 74     0       crispr       absent     100      Cas9
# 75     0     compound       absent     100  Parental
# 76     0     compound       absent     100  Parental
# 77     0     compound       absent     100  Parental
# 78     0     compound       absent     100  Parental
# 79     0     compound       absent     100  Parental
# 80     0     compound       absent     100  Parental
# 81     0     compound       absent     100  Parental
# 82     0     compound       absent     100  Parental
# 88     0     compound       absent     100  Parental
# 89     0     compound       absent     100  Parental
# 99     0          orf       absent     100  Parental
# 100    0          orf       absent     100  Parental
# 101    0       crispr       absent     100      Cas9
# 102    0       crispr       absent     100      Cas9
# 103    0       crispr       absent     100      Cas9
# 104    0       crispr       absent     100      Cas9
# 106    0     compound       absent     100  Parental
# 107    0     compound       absent     100  Parental
# 109    0          orf       absent     100  Parental
# 110    0          orf       absent     100  Parental
# 111    0          orf       absent     100  Parental

# %%
# Add Number of images column
df = df.merge(images_df, on=['Batch','Assay_Plate_Barcode'], how='left')
df.head()
# Out:
#   Assay_Plate_Barcode                   Plate_Map_Name  \
# 0         BR00116991A  JUMP-Target-1_compound_platemap
# 1         BR00116991B  JUMP-Target-1_compound_platemap
# 2         BR00116991C  JUMP-Target-1_compound_platemap
# 3         BR00116991D  JUMP-Target-1_compound_platemap
# 4         BR00116991E  JUMP-Target-1_compound_platemap
#
#                           Batch Anomaly Time_delay Times_imaged Time  \
# 0  2020_12_08_CPJUMP1_Bleaching    none       Day0            2    0
# 1  2020_12_08_CPJUMP1_Bleaching    none       Day0            3    0
# 2  2020_12_08_CPJUMP1_Bleaching    none       Day0            4    0
# 3  2020_12_08_CPJUMP1_Bleaching    none       Day0            5    0
# 4  2020_12_08_CPJUMP1_Bleaching    none       Day0            6    0
#
#   Perturbation Antibiotics Density Cell_line                    Description  \
# 0     compound      absent     100  Parental  A549 24-hour Compound Plate 1
# 1     compound      absent     100  Parental  A549 24-hour Compound Plate 1
# 2     compound      absent     100  Parental  A549 24-hour Compound Plate 1
# 3     compound      absent     100  Parental  A549 24-hour Compound Plate 1
# 4     compound      absent     100  Parental  A549 24-hour Compound Plate 1
#
#    Number_of_images
# 0             21504
# 1             21504
# 2             21504
# 3             21504
# 4             21504

# %%
# Create Cell type column
df['Cell_type'] = list(df.Description.str[0:4])
df.head()
# Out:
#   Assay_Plate_Barcode                   Plate_Map_Name  \
# 0         BR00116991A  JUMP-Target-1_compound_platemap
# 1         BR00116991B  JUMP-Target-1_compound_platemap
# 2         BR00116991C  JUMP-Target-1_compound_platemap
# 3         BR00116991D  JUMP-Target-1_compound_platemap
# 4         BR00116991E  JUMP-Target-1_compound_platemap
#
#                           Batch Anomaly Time_delay Times_imaged Time  \
# 0  2020_12_08_CPJUMP1_Bleaching    none       Day0            2    0
# 1  2020_12_08_CPJUMP1_Bleaching    none       Day0            3    0
# 2  2020_12_08_CPJUMP1_Bleaching    none       Day0            4    0
# 3  2020_12_08_CPJUMP1_Bleaching    none       Day0            5    0
# 4  2020_12_08_CPJUMP1_Bleaching    none       Day0            6    0
#
#   Perturbation Antibiotics Density Cell_line                    Description  \
# 0     compound      absent     100  Parental  A549 24-hour Compound Plate 1
# 1     compound      absent     100  Parental  A549 24-hour Compound Plate 1
# 2     compound      absent     100  Parental  A549 24-hour Compound Plate 1
# 3     compound      absent     100  Parental  A549 24-hour Compound Plate 1
# 4     compound      absent     100  Parental  A549 24-hour Compound Plate 1
#
#    Number_of_images Cell_type
# 0             21504      A549
# 1             21504      A549
# 2             21504      A549
# 3             21504      A549
# 4             21504      A549

# %%
# Create Time column
df.loc[df.Description.str.contains('24'), 'Time'] = '24'
df.loc[df.Description.str.contains('48'), 'Time'] = '48'
df.loc[df.Description.str.contains('96'), 'Time'] = '96'
df.loc[df.Description.str.contains('144'), 'Time'] = '144'
df.loc[df.Time=='0']
# Out:
# Empty DataFrame
# Columns: [Assay_Plate_Barcode, Plate_Map_Name, Batch, Anomaly, Time_delay, Times_imaged, Time, Perturbation, Antibiotics, Density, Cell_line, Description, Number_of_images, Cell_type]
# Index: []

# %%
# Sort rows and columns
df = df.sort_values(by=['Batch','Plate_Map_Name','Assay_Plate_Barcode'], ignore_index=True)[col_order]

# %%
df.to_csv('output/experiment-metadata.tsv', index=False, sep='\t')
